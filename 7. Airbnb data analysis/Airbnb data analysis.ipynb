# %% [markdown]
# # Python Data anslysis of Airbnb dataset.
#
# Data analysis of Airbnb data, using python,
# 1. exploring the dataset, visualizing the null values in heatmap,
# 2. cleaning the dataset from null values,
# 3. using plot to visualize the mean of the numeric data values of the 'Room Price', 'Number of reviews', 'Number of reviews per month', 'Rooms rent by the host', 'Availibility' columns,
# 4. using boxplot to look out for outliers in the dataset,
# 5. checking for duplicated rows in the dataset,
# 6. looking for the maximum and the minimum values of the 'Room Price', 'Number of reviews', 'Number of reviews per month', 'Rooms rent by the host', 'Availibility' columns,
# 7. Exported the analysed and cleaned dataframe.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"E:\Priyanshu IIT (ISM) Dhanbad\Git hub projects\PowerBI\10. Airbnb listing\air-bnb-listings (1).csv")

# %%
df
# Out:
#           Room ID                                               Name  \
# 0         9153958                 .2 La Casa sui Tetti dell'Oltrarno
# 1         9191572                        Firenze Studio Porta Romana
# 2         9306481                  ELEGANT FLAT FLORENCE CITY CENTER
# 3         9524225                    Luxury Modern Studio - Florence
# 4         9602552                                Florence is a dream
# ...           ...                                                ...
# 1048570  26986158     247Hotel Super King Room with private bathroom
# 1048571  29973412   Amazing Luxury apartment Boulevard Saint-Germain
# 1048572  27012835  247Hotel Super King & Single/Twin private bath...
# 1048573  29974983                                Appartement à Paris
# 1048574  27161917                           Greater Manchester House
#
#            Host ID    Neighbourhood        Room type  Room Price  \
# 0         47655975   Centro Storico  Entire home/apt          50
# ...

# %%
df.shape #number of rows and columns
# Out:
# (1048575, 17)

# %%
df.head(2)
# Out:
#    Room ID                                Name   Host ID   Neighbourhood  \
# 0  9153958  .2 La Casa sui Tetti dell'Oltrarno  47655975  Centro Storico
# 1  9191572         Firenze Studio Porta Romana  47816872  Centro Storico
#
#          Room type  Room Price  Minimum nights  Number of reviews  \
# 0  Entire home/apt          50               1                363
# 1  Entire home/apt          70               2                 46
#
#   Date last review  Number of reviews per month  Rooms rent by the host  \
# 0       2020-02-17                         6.69                       2
# 1       2018-03-15                         0.83                       1
#
#    Availibility Updated Date      City Country  \
# 0             0   2020-06-19  Florence   Italy
# 1           364   2020-06-19  Florence   Italy
#
#                             Coordinates                         Location
# 0  43.76678908298443, 11.24589003597409  Italy, Florence, Centro Storico
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   Room ID                      1048575 non-null  int64
#  1   Name                         1048020 non-null  object
#  2   Host ID                      1048575 non-null  int64
#  3   Neighbourhood                1048575 non-null  object
#  4   Room type                    1048575 non-null  object
#  5   Room Price                   1048575 non-null  int64
#  6   Minimum nights               1048575 non-null  int64
#  7   Number of reviews            1048575 non-null  int64
#  8   Date last review             767166 non-null   object
#  9   Number of reviews per month  754705 non-null   float64
#  10  Rooms rent by the host       1048575 non-null  int64
#  11  Availibility                 1048575 non-null  int64
# ...

# %%
df.isnull()
# Out:
#          Room ID   Name  Host ID  Neighbourhood  Room type  Room Price  \
# 0          False  False    False          False      False       False
# 1          False  False    False          False      False       False
# 2          False  False    False          False      False       False
# 3          False  False    False          False      False       False
# 4          False  False    False          False      False       False
# ...          ...    ...      ...            ...        ...         ...
# 1048570    False  False    False          False      False       False
# 1048571    False  False    False          False      False       False
# 1048572    False  False    False          False      False       False
# 1048573    False  False    False          False      False       False
# 1048574    False  False    False          False      False       False
#
#          Minimum nights  Number of reviews  Date last review  \
# ...

# %%
df.isnull().sum() # total null values in each column
# Out:
# Room ID                             0
# Name                              555
# Host ID                             0
# Neighbourhood                       0
# Room type                           0
# Room Price                          0
# Minimum nights                      0
# Number of reviews                   0
# Date last review               281409
# Number of reviews per month    293870
# Rooms rent by the host              0
# Availibility                        0
# Updated Date                    20755
# City                                0
# Country                             0
# Coordinates                         0
# Location                            0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.head(2)
# Out:
#    Room ID                                Name   Host ID   Neighbourhood  \
# 0  9153958  .2 La Casa sui Tetti dell'Oltrarno  47655975  Centro Storico
# 1  9191572         Firenze Studio Porta Romana  47816872  Centro Storico
#
#          Room type  Room Price  Minimum nights  Number of reviews  \
# 0  Entire home/apt          50               1                363
# 1  Entire home/apt          70               2                 46
#
#   Date last review  Number of reviews per month  Rooms rent by the host  \
# 0       2020-02-17                         6.69                       2
# 1       2018-03-15                         0.83                       1
#
#    Availibility Updated Date      City Country  \
# 0             0   2020-06-19  Florence   Italy
# 1           364   2020-06-19  Florence   Italy
#
#                             Coordinates                         Location
# 0  43.76678908298443, 11.24589003597409  Italy, Florence, Centro Storico
# ...

# %%
df2 = df.groupby('Country').mean(numeric_only = True)['Room Price']

# %%
df2
# Out:
# Country
# Argentina          5134.316981
# Australia           210.221651
# Austria             108.274471
# Belgium              88.415714
# Belize              379.470747
# Brazil              775.487190
# Canada              136.876492
# Chile             93927.838720
# China               658.214716
# Czech republic     3670.034917
# Denmark             852.184251
# France              122.935096
# Germany              86.121028
# Greece              174.183150
# Ireland             119.735784
# Italy               102.874394
# Japan             26634.911975
# Mexico             1503.941642
# Netherlands         164.505093
# Norway              933.103888
# Portugal            103.265881
# Singapore           179.287313
# South africa       2499.449007
# Spain               157.890404
# Sweden             1254.373941
# Switzerland         144.726039
# Taiwan             2626.836264
# Turkey              486.253089
# United kingdom      127.946237
# United states       243.167533
# ...

# %%
df2.plot()
# Out:
# <Axes: xlabel='Country'>

# %%
df3 = df.groupby('Country').mean(numeric_only = True)[['Minimum nights', 'Number of reviews', 'Number of reviews per month', 'Rooms rent by the host']]

# %%
df3
# Out:
#                 Minimum nights  Number of reviews  \
# Country
# Argentina             6.490403          15.670148
# Australia             4.744917          24.496415
# Austria               4.976070          33.777927
# Belgium               6.463548          31.193328
# Belize                2.912241          15.432493
# Brazil                4.938895           9.639109
# Canada               10.183266          28.694756
# Chile                 6.694807          13.068550
# China                 7.602184           9.134481
# Czech republic        3.729724          45.698122
# Denmark               3.775151          13.775488
# France                5.048290          20.096402
# Germany               6.994974          19.339656
# Greece                3.428266          16.898164
# Ireland               3.452701          36.615496
# Italy                 3.141416          23.443723
# Japan                 3.327803          26.245581
# ...

# %%
df3.plot()
# Out:
# <Axes: xlabel='Country'>

# %%
df.columns
# Out:
# Index(['Room ID', 'Name', 'Host ID', 'Neighbourhood', 'Room type',
#        'Room Price', 'Minimum nights', 'Number of reviews', 'Date last review',
#        'Number of reviews per month', 'Rooms rent by the host', 'Availibility',
#        'Updated Date', 'City', 'Country', 'Coordinates', 'Location'],
#       dtype='object')

# %%
# check for outliers in dataset with boxplot
df.boxplot(figsize = (20, 10))
# Out:
# <Axes: >

# %%
df.dtypes
# Out:
# Room ID                          int64
# Name                            object
# Host ID                          int64
# Neighbourhood                   object
# Room type                       object
# Room Price                       int64
# Minimum nights                   int64
# Number of reviews                int64
# Date last review                object
# Number of reviews per month    float64
# Rooms rent by the host           int64
# Availibility                     int64
# Updated Date                    object
# City                            object
# Country                         object
# Coordinates                     object
# Location                        object
# dtype: object

# %%
df.select_dtypes(include = 'number')
# Out:
#           Room ID    Host ID  Room Price  Minimum nights  Number of reviews  \
# 0         9153958   47655975          50               1                363
# 1         9191572   47816872          70               2                 46
# 2         9306481   42112573         120               2                132
# 3         9524225   11065786          75               3                 56
# 4         9602552     956926          50               2                 24
# ...           ...        ...         ...             ...                ...
# 1048570  26986158   98057279          45               1                  1
# 1048571  29973412  225348702         300               2                  2
# 1048572  27012835   98057279          47               1                  8
# 1048573  29974983  225357304         160               2                  6
# 1048574  27161917  185059680          80               1                  0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   Room ID                      1048575 non-null  int64
#  1   Name                         1048020 non-null  object
#  2   Host ID                      1048575 non-null  int64
#  3   Neighbourhood                1048575 non-null  object
#  4   Room type                    1048575 non-null  object
#  5   Room Price                   1048575 non-null  int64
#  6   Minimum nights               1048575 non-null  int64
#  7   Number of reviews            1048575 non-null  int64
#  8   Date last review             767166 non-null   object
#  9   Number of reviews per month  754705 non-null   float64
#  10  Rooms rent by the host       1048575 non-null  int64
#  11  Availibility                 1048575 non-null  int64
# ...

# %%
df.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048570    False
# 1048571    False
# 1048572    False
# 1048573    False
# 1048574    False
# Length: 1048575, dtype: bool

# %%
df[df.duplicated()] # answer, no duplicate values
# Out:
# Empty DataFrame
# Columns: [Room ID, Name, Host ID, Neighbourhood, Room type, Room Price, Minimum nights, Number of reviews, Date last review, Number of reviews per month, Rooms rent by the host, Availibility, Updated Date, City, Country, Coordinates, Location]
# Index: []

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 754480 entries, 0 to 1048573
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Room ID                      754480 non-null  int64
#  1   Name                         754480 non-null  object
#  2   Host ID                      754480 non-null  int64
#  3   Neighbourhood                754480 non-null  object
#  4   Room type                    754480 non-null  object
#  5   Room Price                   754480 non-null  int64
#  6   Minimum nights               754480 non-null  int64
#  7   Number of reviews            754480 non-null  int64
#  8   Date last review             754480 non-null  object
#  9   Number of reviews per month  754480 non-null  float64
#  10  Rooms rent by the host       754480 non-null  int64
#  11  Availibility                 754480 non-null  int64
# ...

# %%
df.max()[['Room Price', 'Number of reviews', 'Number of reviews per month', 'Rooms rent by the host', 'Availibility']]
# Out:
# Room Price                     224878135
# Number of reviews                    970
# Number of reviews per month        50.29
# Rooms rent by the host               937
# Availibility                         365
# dtype: object

# %%
df.min()[['Room Price', 'Number of reviews', 'Number of reviews per month', 'Rooms rent by the host', 'Availibility']]
# Out:
# Room Price                        0
# Number of reviews                 1
# Number of reviews per month    0.01
# Rooms rent by the host            1
# Availibility                      0
# dtype: object

# %%
df[df['Country'].str.contains('United kingdom')]
# Out:
#           Room ID                                               Name  \
# 752      37275768           Central luxurious ensuite low price room
# 753      37276808       Stunning 2 Bed flat located by Arthurs Seat.
# 754      37315595    Lovely Edinburgh flat with free private parking
# 755      37362557          Bright and fully refurbished private room
# 756      37389235   Beautiful 3BR Marchmont flat 15 mins to Old Town
# ...           ...                                                ...
# 1048562  26322459                      City Centre Contemporary Home
# 1048564  26494678           Great community, excellent for vacation.
# 1048566  26687566  Modern House Easy Access to Manchester City Ce...
# 1048570  26986158     247Hotel Super King Room with private bathroom
# 1048572  27012835  247Hotel Super King & Single/Twin private bath...
#
#            Host ID                         Neighbourhood        Room type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 754480 entries, 0 to 1048573
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Room ID                      754480 non-null  int64
#  1   Name                         754480 non-null  object
#  2   Host ID                      754480 non-null  int64
#  3   Neighbourhood                754480 non-null  object
#  4   Room type                    754480 non-null  object
#  5   Room Price                   754480 non-null  int64
#  6   Minimum nights               754480 non-null  int64
#  7   Number of reviews            754480 non-null  int64
#  8   Date last review             754480 non-null  object
#  9   Number of reviews per month  754480 non-null  float64
#  10  Rooms rent by the host       754480 non-null  int64
#  11  Availibility                 754480 non-null  int64
# ...

# %%
df.to_csv(r"E:\Priyanshu IIT (ISM) Dhanbad\Git hub projects\PowerBI\10. Airbnb listing/air-bnb-listings (1)_cleaned_data.csv", index=False)
